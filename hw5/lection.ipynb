# %%
## introduction to dataframes and pandas
import pandas as pd

df = pd.read_excel('data.xls')
df
# Out:
#       sepal_length  sepal_width  petal_length  petal_width          species
# 0             6.40         2.70          5.30         1.90   Iris-virginica
# 1             7.38         4.04          5.15         2.37  Iris-versicolor
# 2             5.00         3.40          1.60         0.40      Iris-setosa
# 3             6.12         3.19          5.90         2.01   Iris-virginica
# 4             6.78         3.47          6.13         2.29   Iris-virginica
# ...            ...          ...           ...          ...              ...
# 2419          6.11         5.08          3.15         2.22      Iris-setosa
# 2420          7.17         6.07          4.30         1.78      Iris-setosa
# 2421          6.48         4.98          4.12         3.03      Iris-setosa
# 2422          6.73         4.71          3.67         2.90      Iris-setosa
# 2423          0.00         0.00          0.00         0.00   Iris-virginica
#
# [2424 rows x 5 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2424 entries, 0 to 2423
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  2415 non-null   float64
#  1   sepal_width   2415 non-null   float64
#  2   petal_length  2415 non-null   float64
#  3   petal_width   2415 non-null   float64
#  4   species       2424 non-null   object
# dtypes: float64(4), object(1)
# memory usage: 94.8+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count   2415.000000  2415.000000   2415.000000  2415.000000
# mean       6.470257     3.963540      4.616911     2.189752
# std        2.140522     1.022686      1.987028     1.046936
# min      -10.000000     0.000000      0.000000     0.000000
# 25%        5.950000     3.450000      2.780000     1.460000
# 50%        6.700000     4.000000      5.090000     2.240000
# 75%        7.490000     4.580000      6.150000     2.940000
# max       10.490000     7.470000      9.040000     5.440000

# %%
df.columns # returns column names
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df['sepal_length']# returns column
# Out:
# 0       6.40
# 1       7.38
# 2       5.00
# 3       6.12
# 4       6.78
#         ...
# 2419    6.11
# 2420    7.17
# 2421    6.48
# 2422    6.73
# 2423    0.00
# Name: sepal_length, Length: 2424, dtype: float64

# %%
df['sepal_length'][0]# returns 0 element in column
# Out:
# 6.4

# %%
df.iloc[10] # returns row
# Out:
# sepal_length           5.12
# sepal_width            4.28
# petal_length           2.13
# petal_width            1.26
# species         Iris-setosa
# Name: 10, dtype: object

# %%
df.iloc[10][0] # returns specific row and column (cell) only indexes
# Out:
# 5.12

# %%
df.loc[[1, 2, 3], ['sepal_length', 'sepal_width']] #return 3 rows with 2 columns not only indexes
# Out:
#    sepal_length  sepal_width
# 1          7.38         4.04
# 2          5.00         3.40
# 3          6.12         3.19

# %%
df.iloc[[1, 2, 3], [0, 1]] #return 3 rows with 2 columns
# Out:
#    sepal_length  sepal_width
# 1          7.38         4.04
# 2          5.00         3.40
# 3          6.12         3.19

# %%
df.iloc[1:4, 0:2] #return from 1 to 4 row and from 0 to 2 column (slicing)
# Out:
#    sepal_length  sepal_width
# 1          7.38         4.04
# 2          5.00         3.40
# 3          6.12         3.19

# %%
df[10:50] #return from 10 to 50 row
# Out:
#     sepal_length  sepal_width  petal_length  petal_width          species
# 10          5.12         4.28          2.13         1.26      Iris-setosa
# 11          5.20         2.70          3.90         1.40  Iris-versicolor
# 12          5.83         3.10          4.98         2.47   Iris-virginica
# 13          5.80         2.70          5.10         1.90   Iris-virginica
# 14          4.60         3.10          1.50         0.20      Iris-setosa
# 15          0.00         0.00          0.00         0.00      Iris-setosa
# 16          5.72         4.05          2.43         0.80      Iris-setosa
# 17           NaN          NaN           NaN          NaN      Iris-setosa
# 18          4.80         3.10          1.60         0.20      Iris-setosa
# 19        -10.00         2.90          4.30         1.30  Iris-versicolor
# 20          5.67         3.79          2.26         0.99      Iris-setosa
# 21          5.64         3.90          2.26         1.03      Iris-setosa
# ...

# %%
df.loc[10:50, ['sepal_length', 'sepal_width']] #return from 10 to 50 row only 2 columns
# Out:
#     sepal_length  sepal_width
# 10          5.12         4.28
# 11          5.20         2.70
# 12          5.83         3.10
# 13          5.80         2.70
# 14          4.60         3.10
# 15          0.00         0.00
# 16          5.72         4.05
# 17           NaN          NaN
# 18          4.80         3.10
# 19        -10.00         2.90
# 20          5.67         3.79
# 21          5.64         3.90
# 22          6.40         2.80
# 23          5.70         2.80
# 24          6.53         3.43
# 25          4.60         3.60
# 26          5.50         2.60
# 27          6.59         3.50
# 28          7.70         3.00
# 29          5.54         4.35
# 30          5.55         3.18
# 31          6.30         3.05
# 32          6.90         3.10
# 33          6.00         2.20
# 34          6.99         3.75
# 35          6.69         4.12
# 36          5.40         3.90
# 37          7.90         3.80
# 38          5.42         3.31
# 39          5.61         3.64
# ...

# %%
df[df['sepal_width'] >3]
# Out:
#       sepal_length  sepal_width  petal_length  petal_width          species
# 1             7.38         4.04          5.15         2.37  Iris-versicolor
# 2             5.00         3.40          1.60         0.40      Iris-setosa
# 3             6.12         3.19          5.90         2.01   Iris-virginica
# 4             6.78         3.47          6.13         2.29   Iris-virginica
# 5             5.38         3.47          1.67         0.86      Iris-setosa
# ...            ...          ...           ...          ...              ...
# 2418          7.03         3.41          5.63         3.06  Iris-versicolor
# 2419          6.11         5.08          3.15         2.22      Iris-setosa
# 2420          7.17         6.07          4.30         1.78      Iris-setosa
# 2421          6.48         4.98          4.12         3.03      Iris-setosa
# 2422          6.73         4.71          3.67         2.90      Iris-setosa
#
# [2161 rows x 5 columns]

# %%
df[df['sepal_width'] >3].describe() ## describe returns only by numeric columns
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count   2161.000000  2161.000000   2161.000000  2161.000000
# mean       6.702628     4.188538      4.747557     2.295062
# std        1.869627     0.716347      1.901853     1.006877
# min      -10.000000     3.010000      1.000000     0.100000
# 25%        6.070000     3.640000      2.830000     1.560000
# 50%        6.800000     4.110000      5.200000     2.330000
# 75%        7.580000     4.650000      6.240000     3.010000
# max       10.490000     7.470000      9.040000     5.440000

# %%
df[(df['sepal_width'] > 3) & (df['sepal_length'] < 0)] ##filtering
# Out:
#       sepal_length  sepal_width  petal_length  petal_width          species
# 59          -10.00         3.40          1.40         0.20      Iris-setosa
# 322          -9.88         3.83          5.10         2.23  Iris-versicolor
# 387          -9.23         3.56          5.23         2.35   Iris-virginica
# 625          -9.99         3.23          4.90         1.90  Iris-versicolor
# 665          -9.68         3.69          2.32         0.88      Iris-setosa
# 690          -9.29         3.41          5.37         2.35   Iris-virginica
# 928          -9.68         3.86          5.16         3.20  Iris-versicolor
# 968          -9.21         5.28          2.35         1.35      Iris-setosa
# 993          -9.08         4.45          5.31         2.65   Iris-virginica
# 1231         -9.25         3.71          4.50         2.19  Iris-versicolor
# 1296         -9.21         3.62          5.29         2.00   Iris-virginica
# ...

# %%
df[(df['sepal_width'] > 3) & (df['sepal_length'] < 0)]['species']##ask specific column after filtering
# Out:
# 59          Iris-setosa
# 322     Iris-versicolor
# 387      Iris-virginica
# 625     Iris-versicolor
# 665         Iris-setosa
# 690      Iris-virginica
# 928     Iris-versicolor
# 968         Iris-setosa
# 993      Iris-virginica
# 1231    Iris-versicolor
# 1296     Iris-virginica
# 1534    Iris-versicolor
# 1574        Iris-setosa
# 1599     Iris-virginica
# 1837    Iris-versicolor
# 1877        Iris-setosa
# 1902     Iris-virginica
# 2140    Iris-versicolor
# 2180        Iris-setosa
# 2205     Iris-virginica
# Name: species, dtype: object

# %%
import numpy as np

np.unique(df['species']) ## for ex if in column has only one value we can throw it
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-whatever'], dtype=object)

# %%
df.head() ## only few rows just for look
# Out:
#    sepal_length  sepal_width  petal_length  petal_width          species
# 0          6.40         2.70          5.30         1.90   Iris-virginica
# 1          7.38         4.04          5.15         2.37  Iris-versicolor
# 2          5.00         3.40          1.60         0.40      Iris-setosa
# 3          6.12         3.19          5.90         2.01   Iris-virginica
# 4          6.78         3.47          6.13         2.29   Iris-virginica

# %%
import matplotlib.pyplot as plt

# %%
np.unique(df.species) ##we can ask for column this way or df['species']
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-whatever'], dtype=object)

# %%
df_iris_setosa = df[df['species'] == 'Iris-setosa']
df_iris_virginica = df[df['species'] == 'Iris-virginica']
df_iris_setosa
df_iris_virginica
# Out:
#       sepal_length  sepal_width  petal_length  petal_width         species
# 0             6.40         2.70          5.30         1.90  Iris-virginica
# 3             6.12         3.19          5.90         2.01  Iris-virginica
# 4             6.78         3.47          6.13         2.29  Iris-virginica
# 9             7.16         3.92          5.57         2.30  Iris-virginica
# 12            5.83         3.10          4.98         2.47  Iris-virginica
# ...            ...          ...           ...          ...             ...
# 2405          9.66         6.94          8.20         4.46  Iris-virginica
# 2410          8.09         4.31          7.80         3.88  Iris-virginica
# 2411          8.76         5.50          8.47         3.66  Iris-virginica
# 2413          8.72         4.18          7.62         3.76  Iris-virginica
# 2423          0.00         0.00          0.00         0.00  Iris-virginica
#
# [800 rows x 5 columns]

# %%
## build diagrams
x1_setosa = df_iris_setosa.sepal_length
y1_setosa = df_iris_setosa.petal_length

x1_virginica = df_iris_virginica.sepal_length
y1_virginica = df_iris_virginica.petal_length

plt.scatter(x1_setosa, y1_setosa, label = 'Setosa')
plt.scatter(x1_virginica, y1_virginica, label = 'Virginica')
plt.title('Sepal vs Petal')
plt.xlabel('Sepal length')
plt.ylabel('Petal length')
plt.legend()
plt.show()

# %%
y_ = df['sepal_length']
x_ = df['species']

plt.bar(x_, y_, label = 'Iris', alpha = 0.1, color = 'y')
# Out:
# <BarContainer object of 2424 artists>

# %%
import seaborn as sns

sns.pairplot(df, hue = 'species')

# %%
## linear regression lecture
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count   2415.000000  2415.000000   2415.000000  2415.000000
# mean       6.470257     3.963540      4.616911     2.189752
# std        2.140522     1.022686      1.987028     1.046936
# min      -10.000000     0.000000      0.000000     0.000000
# 25%        5.950000     3.450000      2.780000     1.460000
# 50%        6.700000     4.000000      5.090000     2.240000
# 75%        7.490000     4.580000      6.150000     2.940000
# max       10.490000     7.470000      9.040000     5.440000

# %%
X = df[df.species == 'Iris-setosa'].drop(labels=['sepal_length', 'species'], axis = 1)
Y = df[df.species == 'Iris-setosa']['sepal_length']

# %%
X_test
# Out:
#       sepal_width  petal_length  petal_width
# 395          4.76          2.30         1.55
# 2092         4.40          2.73         2.19
# 888          4.57          1.67         0.44
# 1412         4.00          2.89         0.94
# 1624         5.17          3.25         2.43
# ...           ...           ...          ...
# 324          4.19          2.88         1.92
# 900          3.92          2.27         1.07
# 243          3.00          1.30         0.20
# 1536         4.39          3.21         2.00
# 2051         3.57          2.53         1.56
#
# [240 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=101)

# %%
Y_train
# Out:
# 1022    5.67
# 1758    4.87
# 200     5.10
# 1464    5.06
# 51      4.80
#         ...
# 254     5.20
# 1816    6.13
# 1769    6.96
# 1047    6.16
# 1584    5.56
# Name: sepal_length, Length: 560, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

linear_regression = LinearRegression()

linear_regression.fit(X_train, Y_train)

# %%
linear_regression.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Input In [77], in <cell line: 1>()
# ----> 1 linear_regression.predict(X_test)
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:362, in LinearModel.predict(self, X)
#     348 def predict(self, X):
#     349     """
#     350     Predict using the linear model.
#     351
#    (...)
#     360         Returns predicted values.
#     361     """
# --> 362     return self._decision_function(X)
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:343, in LinearModel._decision_function(self, X)
#     342 def _decision_function(self, X):
# --> 343     check_is_fitted(self)
#     345     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     346     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# ...

# %%
Y_test
# Out:
# 395     5.51
# 2092    6.10
# 888     5.48
# 1412    5.20
# 1624    6.83
#         ...
# 324     5.66
# 900     6.43
# 243     4.40
# 1536    6.66
# 2051    5.69
# Name: sepal_length, Length: 240, dtype: float64

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined
